# %% [markdown]
# # Classic cars classifier using custom dataset from Google Images

# %% [markdown]
# In this notebook I present the steps I took to crate a classifier to distinguish between three classic car models, which share some similarities:
# * Renault 4GTL
# * Citroen 2CV
# * Volkswagen Beetle

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'renault-4gtl'
file = 'urls-renault-4gtl.csv'

# %%
folder = 'citroen-2cv'
file = 'urls-citroen-2cv.csv'

# %%
folder = 'vw-beetle'
file = 'urls-vw-beetle.csv'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('/home/jupyter/classic-cars-classifier/data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1610c2dc2838> in <module>
#       1 path = Path('/home/jupyter/data')
# ----> 2 dest = path/folder
#       3 dest.mkdir(parents=True, exist_ok=True)
#
# NameError: name 'folder' is not defined

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/data/vw-beetle'),
#  PosixPath('/home/jupyter/data/citroen-2cv'),
#  PosixPath('/home/jupyter/data/cleaned.csv'),
#  PosixPath('/home/jupyter/data/export.pkl'),
#  PosixPath('/home/jupyter/data/.ipynb_checkpoints'),
#  PosixPath('/home/jupyter/data/renault-4gtl'),
#  PosixPath('/home/jupyter/data/models')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['renault-4gtl','vw-beetle','citroen-2cv']

# %%
download_images(path/folder/file, dest)
# Out:
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 140, in join
#     res = self._popen.wait(timeout)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 48, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='575', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/fastai/core.py in parallel(func, arr, max_workers)
#     304             futures = [ex.submit(func,o,i) for i,o in enumerate(arr)]
# --> 305             for f in progress_bar(concurrent.futures.as_completed(futures), total=len(arr)): pass
#     306
#
# /opt/anaconda3/lib/python3.7/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#
# /opt/anaconda3/lib/python3.7/concurrent/futures/_base.py in as_completed(fs, timeout)
#     239
# --> 240             waiter.event.wait(wait_timeout)
#     241
#
# /opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#
# /opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-4ed60d4e656b> in <module>
# ----> 1 download_images(path/folder/file, dest)
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/vision/data.py in download_images(urls, dest, max_pics, max_workers, timeout)
#     197     dest = Path(dest)
#     198     dest.mkdir(exist_ok=True)
# --> 199     parallel(partial(_download_image_inner, dest, timeout=timeout), urls, max_workers=max_workers)
#     200
#     201 def resize_to(img, targ_sz:int, use_min:bool=False):
#
# /opt/anaconda3/lib/python3.7/site-packages/fastai/core.py in parallel(func, arr, max_workers)
#     303         with ProcessPoolExecutor(max_workers=max_workers) as ex:
#     304             futures = [ex.submit(func,o,i) for i,o in enumerate(arr)]
# --> 305             for f in progress_bar(concurrent.futures.as_completed(futures), total=len(arr)): pass
#     306
#     307 def subplots(rows:int, cols:int, imgsize:int=4, figsize:Optional[Tuple[int,int]]=None, title=None, **kwargs):
#
# /opt/anaconda3/lib/python3.7/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     609
#     610     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 611         self.shutdown(wait=True)
#     612         return False
#     613
#
# /opt/anaconda3/lib/python3.7/concurrent/futures/process.py in shutdown(self, wait)
#     653             self._queue_management_thread_wakeup.wakeup()
#     654             if wait:
# --> 655                 self._queue_management_thread.join()
#     656         # To reduce the risk of opening too many files, remove references to
#     657         # objects that use file descriptors.
#
# /opt/anaconda3/lib/python3.7/threading.py in join(self, timeout)
#    1030
#    1031         if timeout is None:
# -> 1032             self._wait_for_tstate_lock()
#    1033         else:
#    1034             # the behavior of a negative timeout isn't documented, but
#
# /opt/anaconda3/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1046         if lock is None:  # already determined that the C code is done
#    1047             assert self._is_stopped
# -> 1048         elif lock.acquire(block, timeout):
#    1049             lock.release()
#    1050             self._stop()
#
# KeyboardInterrupt:
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fc7807aa7b8>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 138, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# Error https://topworldauto.com/pics/Renault/renault-r4-gtl-04.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /pics/Renault/renault-r4-gtl-04.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error http://portugal.portalclassicos.com/mercado/conteudos/uploads/2013/10/307427-800x600.jpg HTTPConnectionPool(host='portugal.portalclassicos.com', port=80): Max retries exceeded with url: /mercado/conteudos/uploads/2013/10/307427-800x600.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fc744507048>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error https://topworldauto.com/photos/Renault/d8/97/20614_renault-4-gtl-flickr-photo-sharing.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/Renault/d8/97/20614_renault-4-gtl-flickr-photo-sharing.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/pics/Renault/renault-r4-gtl-05.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /pics/Renault/renault-r4-gtl-05.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://www.picclickimg.com/d/l400/pict/292781918970_/Renault-4-GTL.jpg HTTPSConnectionPool(host='www.picclickimg.com', port=443): Read timed out. (read timeout=4)
# Error https://topworldauto.com/photos/Renault/1f/2d/20614_1985-renault-4-gtl-flickr-photo-sharing.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/Renault/1f/2d/20614_1985-renault-4-gtl-flickr-photo-sharing.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/photos/a9/48/renault-r4-gtl-1989-ao-1989-kms-km-en-mercadolibre_1465d.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/a9/48/renault-r4-gtl-1989-ao-1989-kms-km-en-mercadolibre_1465d.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/photos/96/df/renault-r4-gtl-1987_1600f.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/96/df/renault-r4-gtl-1987_1600f.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/photos/31/6b/bild-renault-r4-gtl-view-fotocommunity_0c312.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/31/6b/bild-renault-r4-gtl-view-fotocommunity_0c312.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/photos/f7/61/renault-r4-gtl_0ed39.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/f7/61/renault-r4-gtl_0ed39.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://topworldauto.com/photos/da/c8/renault-r4-gtl-1988_6e717.jpg HTTPSConnectionPool(host='topworldauto.com', port=443): Max retries exceeded with url: /photos/da/c8/renault-r4-gtl-1988_6e717.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# renault-4gtl
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='518' class='' max='518', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [518/518 00:00<00:00]
#     </div>
# vw-beetle
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='723' class='' max='723', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [723/723 00:00<00:00]
#     </div>
# citroen-2cv
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='646' class='' max='646', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [646/646 00:00<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
#data is an imagedatabuch type
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['citroen-2cv', 'renault-4gtl', 'vw-beetle']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e9751a6da798> in <module>
# ----> 1 data.classes, data.c, len(data.train_ds), len(data.valid_ds)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Train model

# %%
#create cnn gets pretrained model to facilitate image detection - i used here resnet 34 layers
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:35 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.921164</th>
#     <th>0.432226</th>
#     <th>0.164456</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.650789</th>
#     <th>0.388126</th>
#     <th>0.140584</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.503679</th>
#     <th>0.312138</th>
#     <th>0.106101</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.407467</th>
#     <th>0.308939</th>
#     <th>0.106101</th>
#   </tr>
# </table>

# %% [markdown]
# Pretty accurate. The error rate comes down to 10% sometimes. Let's save this first run, with resnet34 and 4 run cycles as 'stage-1'

# %%
learn.save('stage-1')

# %%
#then we unfreeze, to try to optimizze and analyze a little bit more
learn.unfreeze()

# %%
#analyzes accuracy with learning rate
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
What we look for in these graphs is downward slopes

# %% [markdown]
# The loss increases a lot when learning rate goes over 0.003

# %%
#let's try two more cycles with learning rate between 0.003 and 0.0003
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 00:22 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.311131</th>
#     <th>0.313070</th>
#     <th>0.100796</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.234231</th>
#     <th>0.288014</th>
#     <th>0.098143</th>
#   </tr>
# </table>

# %% [markdown]
# It seems to have improved a little bit, which is good and expected

# %%
#let's save this new version, which ran another 2 cycles with a range of learning rates as 'stage-2'
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
#and let's analyze stage 2
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# The gratest confusion are citroen-2cv which are identified as vw-beetles, and also the other way around. These cars are somewhat more similar between themselves than the 4l, so this might be expected.

# %%
interp.plot_top_losses(9, figsize=(15,11))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34fc804e24e7> in <module>
# ----> 1 interp.plot_top_losses(9, figsize=(15,11))
#
# NameError: name 'interp' is not defined

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
#it's going to give us the whole dataset ordered by top losses, since we gave no input
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24' class='' max='24', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24/24 00:05<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# I didn't clean the images all the way to the end because that would take too long

# %% [markdown]
# # Using cleaned data

# %% [markdown]
# Recreate ImageDataBunch from `cleaned.csv` to include changes made in the data

# %%
# If you already cleaned your data, run this cell instead of the one before
#Since we have no dedicated training data, we set valid_pct=0.2, so that 20 % is used as validation set
#We choose random seed 42 so that the images in the validation set are always the same
np.random.seed(42)
data = ImageDataBunch.from_csv("/home/jupyter/classic-cars-classifier/", folder="data", valid_pct=0.2, csv_labels='/home/jupyter/classic-cars-classifier/data/cleaned.csv',
                               ds_tfms=get_transforms(), size=224, num_workers=4, no_check=True).normalize(imagenet_stats)

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['citroen-2cv', 'renault-4gtl', 'vw-beetle'], 3, 897, 224)

# %% [markdown]
# We have 897 images in the training set and 224 images in the validation set

# %%
#Create convolutional learning network
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(8)
# Out:
# Total time: 00:51 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.114506</th>
#     <th>0.469245</th>
#     <th>0.138393</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.686956</th>
#     <th>0.188200</th>
#     <th>0.062500</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.490153</th>
#     <th>0.167148</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.368421</th>
#     <th>0.169074</th>
#     <th>0.040179</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.300309</th>
#     <th>0.172635</th>
#     <th>0.058036</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.244102</th>
#     <th>0.160644</th>
#     <th>0.062500</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.202858</th>
#     <th>0.151681</th>
#     <th>0.053571</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.174389</th>
#     <th>0.148454</th>
#     <th>0.053571</th>
#   </tr>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# We got an error rate of around 5%. I would say that's pretty good.
#
# However, the training loss is higher than the validation loss. That is bad, according to fast.ai... It means we haven't fitted enough, and we either have too few epochs or too slow a learning rate.
#
# It might also be because I only cleaned one of the sets, and I'm not sure which one.

# %%
learn.fit_one_cycle(10)
# Out:
# Total time: 01:01 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.107038</th>
#     <th>0.143355</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.108411</th>
#     <th>0.144140</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.092881</th>
#     <th>0.160328</th>
#     <th>0.058036</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.104077</th>
#     <th>0.159834</th>
#     <th>0.049107</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.103847</th>
#     <th>0.167378</th>
#     <th>0.058036</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.095187</th>
#     <th>0.160193</th>
#     <th>0.049107</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.090379</th>
#     <th>0.148939</th>
#     <th>0.040179</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.082558</th>
#     <th>0.147989</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.078854</th>
#     <th>0.144717</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.070789</th>
#     <th>0.143409</th>
#     <th>0.044643</th>
#   </tr>
# </table>

# %% [markdown]
# After running (a lot) more times, this problem is solved, but accuracy does not increase

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix()

# %%
data.classes
# Out:
# ['citroen-2cv', 'renault-4gtl', 'vw-beetle']

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export('/home/jupyter/classic-cars-classifier/models/')

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
#inference is when you analyze something in order to classify it, using a trained model
defaults.device = torch.device('cpu')

# %%
img = open_image('/home/jupyter/classic-cars-classifier/data/vw-beetle/00000556.jpg')
img
# Out:
# Image (3, 375, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner('/home/jupyter/classic-cars-classifier/models')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category vw-beetle

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)
